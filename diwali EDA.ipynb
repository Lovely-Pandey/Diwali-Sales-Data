# %% [markdown]
# ### Objective : Improve customer experience by analysing sales data .

# %% [markdown]
# # Preparing the data for analysis¶

# %%
import pandas as pd
import seaborn as sns
import numpy as np

path = r"C:\Users\ASUS\Downloads\EDA-Project\Diwali Sales Data.csv"
df = pd.read_csv(path, encoding='iso-8859-1')

print(df)
# Out:
#        User_ID    Cust_name Product_ID Gender  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F   28               0
# 1      1000732       Kartik  P00110942      F   35               1
# 2      1001990        Bindu  P00118542      F   35               1
# 3      1001425       Sudevi  P00237842      M   16               0
# 4      1000588         Joni  P00057942      M   28               1
# ...        ...          ...        ...    ...  ...             ...
# 11246  1000695      Manning  P00296942      M   19               1
# 11247  1004089  Reichenbach  P00171342      M   33               0
# 11248  1001209        Oshin  P00201342      F   40               0
# 11249  1004023       Noonan  P00059442      M   37               0
# 11250  1002744      Brumley  P00281742      F   19               0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# 0         Maharashtra   Western       Healthcare             Auto       1
# ...

# %% [markdown]
# ##### To check the numbers of rows and cloumn we use  df.shape in a dataframe

# %%
df.shape
# Out:
# (11251, 14)

# %% [markdown]
# #### To check top 5 rows and columns of dataframe df.head is used

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender  Age  Marital_Status           State  \
# 0  1002903  Sanskriti  P00125942      F   28               0     Maharashtra
# 1  1000732     Kartik  P00110942      F   35               1  Andhra Pradesh
# 2  1001990      Bindu  P00118542      F   35               1   Uttar Pradesh
# 3  1001425     Sudevi  P00237842      M   16               0       Karnataka
# 4  1000588       Joni  P00057942      M   28               1         Gujarat
#
#        Zone       Occupation Product_Category  Orders   Amount  Status  \
# 0   Western       Healthcare             Auto       1  23952.0     NaN
# 1  Southern             Govt             Auto       3  23934.0     NaN
# 2   Central       Automobile             Auto       3  23924.0     NaN
# 3  Southern     Construction             Auto       2  23912.0     NaN
# 4   Western  Food Processing             Auto       2  23877.0     NaN
#
#    Unnamed
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %% [markdown]
# #### To check data types of each column  and null values in a Dataframe we use df.info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age               11251 non-null  int64
#  5   Marital_Status    11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_Category  11251 non-null  object
#  10  Orders            11251 non-null  int64
#  11  Amount            11239 non-null  float64
#  12  Status            0 non-null      float64
#  13  Unnamed           0 non-null      float64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.2+ MB

# %% [markdown]
# #### To remove those columns having null values we will use drop.

# %%
df.drop(['Status','Unnamed'],axis=1 ,inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age               11251 non-null  int64
#  5   Marital_Status    11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_Category  11251 non-null  object
#  10  Orders            11251 non-null  int64
#  11  Amount            11239 non-null  float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 1.0+ MB

# %% [markdown]
# #### To check sum of all null values across the each  column"

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# #### give  all the rows which are null inside the dataframe

# %%
rows_with_nulls = df[df.isnull().any(axis=1)]
rows_with_nulls
# Out:
#      User_ID Cust_name Product_ID Gender  Age  Marital_Status           State  \
# 7    1002092  Shivangi  P00273442      F   61               0     Maharashtra
# 14   1003858      Cano  P00293742      M   46               1  Madhya Pradesh
# 16   1005447       Amy  P00275642      F   48               1  Andhra Pradesh
# 109  1005265    Sakshi  P00296242      F   48               1           Delhi
# 111  1005261   Apoorva  P00057942      F   41               1           Delhi
# 184  1005538    Kartik  P00269542      F   49               1       Karnataka
# 293  1000326  Jonathan  P00120542      M   53               0         Gujarat
# 344  1002507   Lakshmi  P00045842      F   35               1         Gujarat
# 345  1004498   Srishti  P00030842      F   55               0           Delhi
# 452  1004601    Gaurav  P00014442      F   40               1  Madhya Pradesh
# 464  1004528    Anurag  P00338442      F   33               1   Uttar Pradesh
# ...

# %%
pd.isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %% [markdown]
# ### #calculate mean for each category and fill NA with for  that cateogry.

# %%
df['Amount'] = df.groupby('Product_Category')['Amount'].transform(lambda x: x.fillna(x.mean()))

# %%
# just to cross check the data either it got replaced by mean value or not , here I am checking the row ow its confirmed.
selected_rows = df[(df['User_ID']==1002092) & (df['Product_ID']=='P00273442')]
print(selected_rows)
# Out:
#    User_ID Cust_name Product_ID Gender  Age  Marital_Status        State  \
# 7  1002092  Shivangi  P00273442      F   61               0  Maharashtra
#
#       Zone Occupation Product_Category  Orders        Amount
# 7  Western  IT Sector             Auto       1  20191.855567

# %% [markdown]
# #### To recheck  and confirm sum of all null values across the each  column"

# %%
pd.isnull(df).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %% [markdown]
# ##### As you can see 'Amount' contain float Data types so I will change it into integer.

# %%
# change datatype
df['Amount'] = df['Amount'].astype('int')

# %%
df['Amount'].dtypes
# Out:
# dtype('int32')

# %%
# rename the column
df.rename(columns={'Marital_Status' : 'Married'})
# Out:
#        User_ID    Cust_name Product_ID Gender  Age  Married           State  \
# 0      1002903    Sanskriti  P00125942      F   28        0     Maharashtra
# 1      1000732       Kartik  P00110942      F   35        1  Andhra Pradesh
# 2      1001990        Bindu  P00118542      F   35        1   Uttar Pradesh
# 3      1001425       Sudevi  P00237842      M   16        0       Karnataka
# 4      1000588         Joni  P00057942      M   28        1         Gujarat
# ...        ...          ...        ...    ...  ...      ...             ...
# 11246  1000695      Manning  P00296942      M   19        1     Maharashtra
# 11247  1004089  Reichenbach  P00171342      M   33        0         Haryana
# 11248  1001209        Oshin  P00201342      F   40        0  Madhya Pradesh
# 11249  1004023       Noonan  P00059442      M   37        0       Karnataka
# 11250  1002744      Brumley  P00281742      F   19        0     Maharashtra
#
# ...

# %% [markdown]
# ###  Can you provide a summary of the statistical characteristics of the  in the dataset?

# %%
# describe() method returns description of the data in  the dataframe(ie  count,mean.std deviation etc)
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11251.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9460.454626
# std    1.716125e+03     12.754122        0.493632      1.115047   5224.434220
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.500000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8110.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12691.500000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %% [markdown]
# ### Can you provide a summary of the statistical characteristics of the numerical columns [Age','Orders','Amount]in the dataset?

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11251.000000  11251.000000  11251.000000
# mean      35.421207      2.489290   9460.454626
# std       12.754122      1.115047   5224.434220
# min       12.000000      1.000000    188.000000
# 25%       27.000000      1.500000   5443.500000
# 50%       33.000000      2.000000   8110.000000
# 75%       43.000000      3.000000  12691.500000
# max       92.000000      4.000000  23952.000000

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age', 'Marital_Status',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount'],
#       dtype='object')

# %% [markdown]
# ###  What is the total amount spent by customers aged 25 and above?

# %%
total_amount_above_25 =df[df['Age'] >= 25]['Amount'].sum()
print(f'Total amount spent by customers aged 25 and above: {total_amount_above_25}')
# Out:
# Total amount spent by customers aged 25 and above: 88595713

# %%
#Filtering the DataFrame on the basis of Age.
df[df['Age']>=25]
# Out:
#        User_ID    Cust_name Product_ID Gender  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F   28               0
# 1      1000732       Kartik  P00110942      F   35               1
# 2      1001990        Bindu  P00118542      F   35               1
# 4      1000588         Joni  P00057942      M   28               1
# 5      1000588         Joni  P00057942      M   28               1
# ...        ...          ...        ...    ...  ...             ...
# 11244  1005446      Sheetal  P00297742      M   53               0
# 11245  1004140    Bertelson  P00057442      F   31               1
# 11247  1004089  Reichenbach  P00171342      M   33               0
# 11248  1001209        Oshin  P00201342      F   40               0
# 11249  1004023       Noonan  P00059442      M   37               0
#
#                   State      Zone       Occupation Product_Category  Orders  \
# 0           Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
#Filtering the DataFrame on the basis of Zone.	.
df[df['Zone']=='Western']
# Out:
#        User_ID  Cust_name Product_ID Gender  Age  Marital_Status        State  \
# 0      1002903  Sanskriti  P00125942      F   28               0  Maharashtra
# 4      1000588       Joni  P00057942      M   28               1      Gujarat
# 7      1002092   Shivangi  P00273442      F   61               0  Maharashtra
# 33     1002638     Damala  P00346242      F   35               1  Maharashtra
# 60     1000379      Thais  P00121642      M   39               0  Maharashtra
# ...        ...        ...        ...    ...  ...             ...          ...
# 11223  1001542       Buch  P00113642      F   20               1  Maharashtra
# 11233  1002106       Luke  P00164342      M   19               0  Maharashtra
# 11243  1005446    Sheetal  P00297742      M   53               0      Gujarat
# 11246  1000695    Manning  P00296942      M   19               1  Maharashtra
# 11250  1002744    Brumley  P00281742      F   19               0  Maharashtra
#
# ...

# %% [markdown]
# #### Filtrating DataFrame on the basis of Zone

# %%
df[df['Zone']=='Central']
# Out:
#        User_ID   Cust_name Product_ID Gender  Age  Marital_Status  \
# 2      1001990       Bindu  P00118542      F   35               1
# 6      1001132        Balk  P00018042      F   25               1
# 8      1003224      Kushal  P00205642      M   35               0
# 10     1003829    Harshita  P00200842      M   34               0
# 14     1003858        Cano  P00293742      M   46               1
# ...        ...         ...        ...    ...  ...             ...
# 11241  1003032    Matthias  P00058042      F   33               0
# 11242  1004344  Hildebrand  P00185442      F   27               1
# 11244  1005446     Sheetal  P00297742      M   53               0
# 11245  1004140   Bertelson  P00057442      F   31               1
# 11248  1001209       Oshin  P00201342      F   40               0
#
#                 State     Zone   Occupation Product_Category  Orders  Amount
# 2       Uttar Pradesh  Central   Automobile             Auto       3   23924
# ...

# %% [markdown]
# ### How many orders were placed by customers aged 25  above and in the Central zone?

# %%
df[(df['Age']>=25)&(df['Zone']=='Central')]
# Out:
#        User_ID   Cust_name Product_ID Gender  Age  Marital_Status  \
# 2      1001990       Bindu  P00118542      F   35               1
# 6      1001132        Balk  P00018042      F   25               1
# 8      1003224      Kushal  P00205642      M   35               0
# 10     1003829    Harshita  P00200842      M   34               0
# 14     1003858        Cano  P00293742      M   46               1
# ...        ...         ...        ...    ...  ...             ...
# 11241  1003032    Matthias  P00058042      F   33               0
# 11242  1004344  Hildebrand  P00185442      F   27               1
# 11244  1005446     Sheetal  P00297742      M   53               0
# 11245  1004140   Bertelson  P00057442      F   31               1
# 11248  1001209       Oshin  P00201342      F   40               0
#
#                 State     Zone   Occupation Product_Category  Orders  Amount
# 2       Uttar Pradesh  Central   Automobile             Auto       3   23924
# ...

# %% [markdown]
# ### Filter those  customers are from "Delhi" and Occupation is  'Aviation'.

# %% [markdown]
# #### Filtrating DataFrame on the basis of state and Occupation

# %%
df[(df['State']=='Delhi')&(df['Occupation']=='Aviation')]
# Out:
#        User_ID  Cust_name Product_ID Gender  Age  Marital_Status  State  \
# 64     1002395   Vaibhavi  P00220342      F   38               1  Delhi
# 72     1000179      Debra  P00261642      F   30               0  Delhi
# 91     1001183     Mahima  P00084842      F   43               1  Delhi
# 125    1002445      Shiva  P00184042      F   28               0  Delhi
# 130    1003724   Devendra  P00232442      F   36               0  Delhi
# ...        ...        ...        ...    ...  ...             ...    ...
# 11194  1001053     Sanjit  P00277842      F   42               1  Delhi
# 11197  1005178    Edelman  P00045842      F   52               1  Delhi
# 11224  1004378    Kritika  P00274042      F   18               0  Delhi
# 11234  1001628    Sandeep  P00226342      F   21               0  Delhi
# 11245  1004140  Bertelson  P00057442      F   31               1  Delhi
#
#           Zone Occupation  Product_Category  Orders  Amount
# ...

# %% [markdown]
# ###  What is the total amount spent by customers in each occupation category?

# %%
df.groupby('Occupation')['Amount'].sum().sort_values(ascending=False)
# Out:
# Occupation
# IT Sector          14838503
# Healthcare         13034586
# Aviation           12602298
# Banking            10800024
# Govt                8517212
# Hospitality         6410224
# Media               6295832
# Automobile          5382224
# Chemical            5312890
# Lawyer              4981665
# Retail              4783170
# Food Processing     4070670
# Construction        3597511
# Textile             3219679
# Agriculture         2593087
# Name: Amount, dtype: int32

# %% [markdown]
# ###   How many orders were placed by customers in each state?

# %%
df.groupby('State',)['Orders'].sum().sort_values(ascending= False)
# Out:
# State
# Uttar Pradesh       4813
# Maharashtra         3811
# Karnataka           3241
# Delhi               2744
# Madhya Pradesh      2259
# Andhra Pradesh      2054
# Himachal Pradesh    1568
# Kerala              1137
# Haryana             1109
# Gujarat             1070
# Bihar               1062
# Jharkhand            953
# Uttarakhand          824
# Rajasthan            555
# Punjab               495
# Telangana            312
# Name: Orders, dtype: int64

# %%
### The customers from  Uttar Pradesh placed more orders
